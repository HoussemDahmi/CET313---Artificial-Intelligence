# %% [markdown]
# **Exercice1+2**

# %% [markdown]
# The best approach to solve the coin change problem is by starting with the largest coin value and keeping track of the remaining amount.

# %% [markdown]
# one coin of 50p => Remaining 43p |
# Two coins of 20p => Remaining 3p |
# one coin of 2p => Remaining 1p |
# one coin of 1p => Remaining 0p

# %% [markdown]
# Thus, the minimum number of coins needed is one coin of 50p + 2 coins of 20p + 1 coin of 2p + 1 coin of 1p = 5 coins

# %% [markdown]
# **Exercice3**

# %%
def coin_change(coins, amount):
    coins.sort(reverse=True) # Sort the coins in descending order
    coin_count = 0 # Variable to keep track of the total number of coins used
    change = [] # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f" Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the coins.")
coins = [1, 2, 5, 10, 20, 50, 100, 200] # List of available coins
amount = 93 # Amount for which we need to find the minimum number of coins
coin_change(coins, amount)
# Out:
#  Minimum number of coins required: 5
# Coins used: [50, 20, 20, 2, 1]

# %% [markdown]
# **Exercice4**

# %%
def coin_change(coins, amount):
    coins.sort(reverse=True) # Sort the coins in descending order
    coin_count = 0 # Variable to keep track of the total number of coins used
    change = [] # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f" Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the coins.")
coins = [1, 2, 5, 10, 20, 50, 100, 200] # List of available coins
amount = 86 # Amount for which we need to find the minimum number of coins
coin_change(coins, amount)
# Out:
#  Minimum number of coins required: 5
# Coins used: [50, 20, 10, 5, 1]

# %%
def coin_change(coins, amount):
    coins.sort(reverse=True) # Sort the coins in descending order
    coin_count = 0 # Variable to keep track of the total number of coins used
    change = [] # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f" Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the coins.")
coins = [1, 2, 5, 10, 20, 50, 100, 200] # List of available coins
amount = 72 # Amount for which we need to find the minimum number of coins
coin_change(coins, amount)
# Out:
#  Minimum number of coins required: 3
# Coins used: [50, 20, 2]

# %%
def coin_change(coins, amount):
    coins.sort(reverse=True) # Sort the coins in descending order
    coin_count = 0 # Variable to keep track of the total number of coins used
    change = [] # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f" Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the coins.")
coins = [1, 2, 5, 10, 20, 50, 100, 200] # List of available coins
amount = 59 # Amount for which we need to find the minimum number of coins
coin_change(coins, amount)
# Out:
#  Minimum number of coins required: 4
# Coins used: [50, 5, 2, 2]

# %% [markdown]
# **Exercise5**

# %% [markdown]
# Sorting Coins: The script begins by arranging the list of coins in descending order, thereby prioritizing the utilization of larger denominations first.
#
# Initial Setup: A counter, coin_count, is established to monitor the total number of coins utilized, along with a list named change to record the specific coins employed to achieve the desired amount.
#
# Coin Usage Loop: The script proceeds to iterate through each coin denomination:
#
# During each iteration, a while loop is employed to deduct the coin's value from the amount as long as the amount remains greater than or equal to the value of the coin.
#
# With each coin utilized, the amount is decreased, the coin count is increased, and the coin is appended to the change list.
#
# Result Check: Following the attempt to fulfill the amount with the available coins:
#
# If the amount is successfully reduced to zero, the script outputs the total number of coins used along with the specific denominations utilized.
#
# Conversely, if the amount cannot be entirely reduced to zero with the available coins, an error message is displayed, indicating that achieving the desired change is not feasible.

# %% [markdown]
# **Exercise6**

# %% [markdown]
# What we do to enhance the script is introducing the divmod f° for its efficiency in determining how many coins can be used and what remains to be changed.

# %% [markdown]
# **Part2 - Exercise7**

# %%
# %pip install network
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------- ----- 1.6/1.8 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
A = Node("A", 5)
B = Node("B", 4)
C = Node("C", 3)
D = Node("D", 2)
E = Node("E", 1)
F = Node("F", 0)
# Adding neighbors and their costs
A.add_neighbor(B, 1)
A.add_neighbor(C, 2)
B.add_neighbor(D, 5)
C.add_neighbor(D, 2)
C.add_neighbor(E, 4)
D.add_neighbor(F, 3)
E.add_neighbor(F, 2)
# Visualization without the solution
G = nx.Graph()
edges = [(A.name, B.name, {'weight': 1}), (A.name, C.name, {'weight': 2}),
(B.name, D.name, {'weight': 5}), (C.name, D.name, {'weight': 2}),
(C.name, E.name, {'weight': 4}), (D.name, F.name, {'weight': 3}),
(E.name, F.name, {'weight': 2})]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(A, F)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['A', 'C', 'D', 'F']

# %% [markdown]
# **Exercise8**

# %%
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
Sunderland = Node("Sunderland", 3)
South_Shields = Node("South Shields", 5)
Newcastle = Node("Newcastle", 2)
Washington = Node("Washington", 0)
Durham = Node("Durham", 1)
Peterlee = Node("Peterlee", 2)

# Adding neighbors and their costs
Sunderland.add_neighbor(South_Shields, 2)
Sunderland.add_neighbor(Newcastle, 3)
Sunderland.add_neighbor(Peterlee, 3)
South_Shields.add_neighbor(Sunderland, 2)
South_Shields.add_neighbor(Newcastle, 2)
Newcastle.add_neighbor(Sunderland, 3)
Newcastle.add_neighbor(South_Shields, 2)
Newcastle.add_neighbor(Washington, 2)
Washington.add_neighbor(Newcastle, 2)
Washington.add_neighbor(Durham, 3)
Durham.add_neighbor(Washington, 3)
Durham.add_neighbor(Peterlee, 2)
Peterlee.add_neighbor(Durham, 2)
Peterlee.add_neighbor(Sunderland, 3)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, South_Shields.name, {'weight': 2}),
    (Sunderland.name, Newcastle.name, {'weight': 3}),
    (Sunderland.name, Peterlee.name, {'weight': 3}),
    (South_Shields.name, Newcastle.name, {'weight': 2}),
    (South_Shields.name, Sunderland.name, {'weight': 2}),
    (Newcastle.name, Washington.name, {'weight': 2}),
    (Newcastle.name, Sunderland.name, {'weight': 3}),
    (Newcastle.name, South_Shields.name, {'weight': 2}),
    (Washington.name, Newcastle.name, {'weight': 2}),
    (Washington.name, Durham.name, {'weight': 3}),
    (Durham.name, Washington.name, {'weight': 3}),
    (Durham.name, Peterlee.name, {'weight': 2}),
    (Peterlee.name, Durham.name, {'weight': 2}),
    (Peterlee.name, Sunderland.name, {'weight': 3})
]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Sunderland, Washington)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['Sunderland', 'Newcastle', 'Washington']

# %% [markdown]
# **Exercice9**
# using real distances between cities.

# %% [markdown]
# The distances between cities are flight or air distances and not road distances and they're in km. I used distancecalculator.globefeed.com

# %%
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
Sunderland = Node("Sunderland", 3)
South_Shields = Node("South Shields", 5)
Newcastle = Node("Newcastle", 2)
Washington = Node("Washington", 0)
Durham = Node("Durham", 1)
Peterlee = Node("Peterlee", 2)

# Adding neighbors and their costs
Sunderland.add_neighbor(South_Shields, 10.44)
Sunderland.add_neighbor(Newcastle, 16.28)
Sunderland.add_neighbor(Peterlee, 16.71)
South_Shields.add_neighbor(Sunderland, 10.44)
South_Shields.add_neighbor(Newcastle, 11.55)
Newcastle.add_neighbor(Sunderland, 16.28)
Newcastle.add_neighbor(South_Shields, 11.55)
Newcastle.add_neighbor(Washington, 10.26)
Washington.add_neighbor(Newcastle, 10.26)
Washington.add_neighbor(Durham, 14.15)
Durham.add_neighbor(Washington, 14.15)
Durham.add_neighbor(Peterlee, 15.44)
Peterlee.add_neighbor(Durham, 15.44)
Peterlee.add_neighbor(Sunderland, 16.71)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, South_Shields.name, {'weight': 10.44}),
    (Sunderland.name, Newcastle.name, {'weight': 16.28}),
    (Sunderland.name, Peterlee.name, {'weight': 16.71}),
    (South_Shields.name, Newcastle.name, {'weight': 11.55}),
    (South_Shields.name, Sunderland.name, {'weight': 10.44}),
    (Newcastle.name, Washington.name, {'weight': 10.26}),
    (Newcastle.name, Sunderland.name, {'weight': 16.28}),
    (Newcastle.name, South_Shields.name, {'weight': 11.55}),
    (Washington.name, Newcastle.name, {'weight': 10.26}),
    (Washington.name, Durham.name, {'weight': 14.15}),
    (Durham.name, Washington.name, {'weight': 14.15}),
    (Durham.name, Peterlee.name, {'weight': 15.44}),
    (Peterlee.name, Durham.name, {'weight': 15.44}),
    (Peterlee.name, Sunderland.name, {'weight': 16.71})
]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Sunderland, Washington)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['Sunderland', 'Newcastle', 'Washington']

# %% [markdown]
# **Exercise10**
# Experimenting with 3 different starting and ending points.

# %% [markdown]
# South Shields to Durham

# %%
#South Shield to Durham
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
Sunderland = Node("Sunderland", 3)
South_Shields = Node("South Shields", 5)
Newcastle = Node("Newcastle", 2)
Washington = Node("Washington", 0)
Durham = Node("Durham", 1)
Peterlee = Node("Peterlee", 2)

# Adding neighbors and their costs
Sunderland.add_neighbor(South_Shields, 10.44)
Sunderland.add_neighbor(Newcastle, 16.28)
Sunderland.add_neighbor(Peterlee, 16.71)
South_Shields.add_neighbor(Sunderland, 10.44)
South_Shields.add_neighbor(Newcastle, 11.55)
Newcastle.add_neighbor(Sunderland, 16.28)
Newcastle.add_neighbor(South_Shields, 11.55)
Newcastle.add_neighbor(Washington, 10.26)
Washington.add_neighbor(Newcastle, 10.26)
Washington.add_neighbor(Durham, 14.15)
Durham.add_neighbor(Washington, 14.15)
Durham.add_neighbor(Peterlee, 15.44)
Peterlee.add_neighbor(Durham, 15.44)
Peterlee.add_neighbor(Sunderland, 16.71)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, South_Shields.name, {'weight': 10.44}),
    (Sunderland.name, Newcastle.name, {'weight': 16.28}),
    (Sunderland.name, Peterlee.name, {'weight': 16.71}),
    (South_Shields.name, Newcastle.name, {'weight': 11.55}),
    (South_Shields.name, Sunderland.name, {'weight': 10.44}),
    (Newcastle.name, Washington.name, {'weight': 10.26}),
    (Newcastle.name, Sunderland.name, {'weight': 16.28}),
    (Newcastle.name, South_Shields.name, {'weight': 11.55}),
    (Washington.name, Newcastle.name, {'weight': 10.26}),
    (Washington.name, Durham.name, {'weight': 14.15}),
    (Durham.name, Washington.name, {'weight': 14.15}),
    (Durham.name, Peterlee.name, {'weight': 15.44}),
    (Peterlee.name, Durham.name, {'weight': 15.44}),
    (Peterlee.name, Sunderland.name, {'weight': 16.71})
]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(South_Shields, Durham)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['South Shields', 'Newcastle', 'Washington', 'Durham']

# %% [markdown]
# Newcastle to Peterlee

# %%
#Newcastle to Peterlee
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
Sunderland = Node("Sunderland", 3)
South_Shields = Node("South Shields", 5)
Newcastle = Node("Newcastle", 2)
Washington = Node("Washington", 0)
Durham = Node("Durham", 1)
Peterlee = Node("Peterlee", 2)

# Adding neighbors and their costs
Sunderland.add_neighbor(South_Shields, 10.44)
Sunderland.add_neighbor(Newcastle, 16.28)
Sunderland.add_neighbor(Peterlee, 16.71)
South_Shields.add_neighbor(Sunderland, 10.44)
South_Shields.add_neighbor(Newcastle, 11.55)
Newcastle.add_neighbor(Sunderland, 16.28)
Newcastle.add_neighbor(South_Shields, 11.55)
Newcastle.add_neighbor(Washington, 10.26)
Washington.add_neighbor(Newcastle, 10.26)
Washington.add_neighbor(Durham, 14.15)
Durham.add_neighbor(Washington, 14.15)
Durham.add_neighbor(Peterlee, 15.44)
Peterlee.add_neighbor(Durham, 15.44)
Peterlee.add_neighbor(Sunderland, 16.71)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, South_Shields.name, {'weight': 10.44}),
    (Sunderland.name, Newcastle.name, {'weight': 16.28}),
    (Sunderland.name, Peterlee.name, {'weight': 16.71}),
    (South_Shields.name, Newcastle.name, {'weight': 11.55}),
    (South_Shields.name, Sunderland.name, {'weight': 10.44}),
    (Newcastle.name, Washington.name, {'weight': 10.26}),
    (Newcastle.name, Sunderland.name, {'weight': 16.28}),
    (Newcastle.name, South_Shields.name, {'weight': 11.55}),
    (Washington.name, Newcastle.name, {'weight': 10.26}),
    (Washington.name, Durham.name, {'weight': 14.15}),
    (Durham.name, Washington.name, {'weight': 14.15}),
    (Durham.name, Peterlee.name, {'weight': 15.44}),
    (Peterlee.name, Durham.name, {'weight': 15.44}),
    (Peterlee.name, Sunderland.name, {'weight': 16.71})
]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Newcastle, Peterlee)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['Newcastle', 'Sunderland', 'Peterlee']

# %% [markdown]
# Washington to South Shields

# %%
#Washington to South Shields
import networkx as nx
import matplotlib.pyplot as plt
import heapq

#Class representing a node in the graph
class Node: 
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
        
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
        
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost
    
    # A* search algorithm
def astar_search(start, goal):
        open_list = []
        closed_set = set()
        start.g_cost = 0
        heapq.heappush(open_list, start)
        while open_list:
            current_node = heapq.heappop(open_list)
            if current_node == goal:
                path = []
                while current_node is not None:
                    path.append(current_node.name)
                    current_node = current_node.parent
                return path[::-1]
            closed_set.add(current_node)
            for neighbor, cost in current_node.adjacent.items():
                tentative_g_cost = current_node.g_cost + cost
                if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                    continue
                if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                    neighbor.g_cost = tentative_g_cost
                    neighbor.parent = current_node
                    if neighbor not in open_list:
                        heapq.heappush(open_list, neighbor)
        return None  
    
# Creating nodes
Sunderland = Node("Sunderland", 3)
South_Shields = Node("South Shields", 5)
Newcastle = Node("Newcastle", 2)
Washington = Node("Washington", 0)
Durham = Node("Durham", 1)
Peterlee = Node("Peterlee", 2)

# Adding neighbors and their costs
Sunderland.add_neighbor(South_Shields, 10.44)
Sunderland.add_neighbor(Newcastle, 16.28)
Sunderland.add_neighbor(Peterlee, 16.71)
South_Shields.add_neighbor(Sunderland, 10.44)
South_Shields.add_neighbor(Newcastle, 11.55)
Newcastle.add_neighbor(Sunderland, 16.28)
Newcastle.add_neighbor(South_Shields, 11.55)
Newcastle.add_neighbor(Washington, 10.26)
Washington.add_neighbor(Newcastle, 10.26)
Washington.add_neighbor(Durham, 14.15)
Durham.add_neighbor(Washington, 14.15)
Durham.add_neighbor(Peterlee, 15.44)
Peterlee.add_neighbor(Durham, 15.44)
Peterlee.add_neighbor(Sunderland, 16.71)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, South_Shields.name, {'weight': 10.44}),
    (Sunderland.name, Newcastle.name, {'weight': 16.28}),
    (Sunderland.name, Peterlee.name, {'weight': 16.71}),
    (South_Shields.name, Newcastle.name, {'weight': 11.55}),
    (South_Shields.name, Sunderland.name, {'weight': 10.44}),
    (Newcastle.name, Washington.name, {'weight': 10.26}),
    (Newcastle.name, Sunderland.name, {'weight': 16.28}),
    (Newcastle.name, South_Shields.name, {'weight': 11.55}),
    (Washington.name, Newcastle.name, {'weight': 10.26}),
    (Washington.name, Durham.name, {'weight': 14.15}),
    (Durham.name, Washington.name, {'weight': 14.15}),
    (Durham.name, Peterlee.name, {'weight': 15.44}),
    (Peterlee.name, Durham.name, {'weight': 15.44}),
    (Peterlee.name, Sunderland.name, {'weight': 16.71})
]
G.add_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Washington, South_Shields)
print("A* path:", path)
    
# Visualisation with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# A* path: ['Washington', 'Newcastle', 'South Shields']

# %% [markdown]
# **Part3 Genetic Algorithm**
# **Exercise11**

# %%
import random
# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = '''01'''
# Target string to be generated
TARGET = "001010"

class Individual(object):
    #Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation
        global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome(self):
        #create chromosome or string of genes
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
    # Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
    generation += 1
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: 001010	Fitness: 0
# Generation: 2	String: 001010	Fitness: 0

# %% [markdown]
# **Exercise12**

# %% [markdown]
# Including all alphabets and updating target value to 'Welcome to AI'

# %%
import random
# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = 'abcdefghijklmnopqrstuvwxyz'
# Target string to be generated
TARGET = "Welcome to AI"

class Individual(object):
    #Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation
        global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome(self):
        #create chromosome or string of genes
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation

    generation += 1
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 94
#      90     print("Generation: {}\tString: {}\tFitness: {}".format(generation,
#      91     "".join(population[0].chromosome),
#      92     population[0].fitness))
#      93 if __name__ == '__main__':
# ---> 94     main()
#
# Cell In[35], line 85, in main()
#      83     parent1 = random.choice(population[:50])
#      84     parent2 = random.choice(population[:50])
# ---> 85     child = parent1.mate(parent2)
#      86     new_generation.append(child)
#      87 population = new_generation
#
# Cell In[35], line 30, in Individual.mate(self, par2)
#      26 def mate(self, par2):
#      27     #Perform mating and produce new offspring
#      28     # chromosome for offspring
#      29     child_chromosome = []
# ---> 30     for gp1, gp2 in zip(self.chromosome, par2.chromosome):
# ...

# %% [markdown]
# **Exercise13**

# %% [markdown]
# Updating the script with time() f° to measure the duration of finding the sol°

# %%
import random
import time
# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = 'abcdefghijklmnopqrstuvwxyz'
# Target string to be generated
TARGET = "Welcome to AI"

class Individual(object):
    #Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation
        global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome(self):
        #create chromosome or string of genes
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
            
    #start timer
    start_time= time.time()
    
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation
        
        generation += 1
        
        #end time
        end_time = time.time()
        duration = end_time - start_time
        
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
    
    print('duration: {:.2f} seconds'.format(duration))
    
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 106
#     103     print('duration: {:.2f} seconds'.format(duration))
#     105 if __name__ == '__main__':
# --> 106     main()
#
# Cell In[36], line 90, in main()
#      88     parent1 = random.choice(population[:50])
#      89     parent2 = random.choice(population[:50])
# ---> 90     child = parent1.mate(parent2)
#      91     new_generation.append(child)
#      92 population = new_generation
#
# Cell In[36], line 31, in Individual.mate(self, par2)
#      27 def mate(self, par2):
#      28     #Perform mating and produce new offspring
#      29     # chromosome for offspring
#      30     child_chromosome = []
# ---> 31     for gp1, gp2 in zip(self.chromosome, par2.chromosome):
#      32         # random probability
#      33         prob = random.random()
# ...

# %% [markdown]
# **Exercise14**

# %% [markdown]
# A 5 word target.

# %%
#changing target string to contain 5 words

import random
import time
# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = 'abcdefghijklmnopqrstuvwxyz'
# Target string to be generated
TARGET = "Welcome to AI session week3"

class Individual(object):
    #Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation
        global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome(self):
        #create chromosome or string of genes
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
            
    #start timer
    start_time= time.time()
    
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation
        
        generation += 1
        
        #end time
        end_time = time.time()
        duration = end_time - start_time
        
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
    
    print('duration: {:.2f} seconds'.format(duration))
    
if __name__ == '__main__':
    main()

# %% [markdown]
# **Exercise15**

# %% [markdown]
# adding numbers to GENES

# %%
#changing target string to contain 5 words

import random
import time
# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = 'abcdefghijklmnopqrstuvwxyz0123456789'
# Target string to be generated
TARGET = "Welcome to AI session week3"

class Individual(object):
    #Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation
        global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome(self):
        #create chromosome or string of genes
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
            
    #start timer
    start_time= time.time()
    
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation
        
        generation += 1
        
        #end time
        end_time = time.time()
        duration = end_time - start_time
        
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
    
    print('duration: {:.2f} seconds'.format(duration))
    
if __name__ == '__main__':
    main()
